# %%
import pandas as pd
import pandasql as ps
import numpy as np
import warnings

# %%
df = pd.read_csv('NFL_Bet_Data.csv')
df.head()
# Out:
#   schedule_date  schedule_season schedule_week  schedule_playoff  \
# 0      9/2/1966             1966             1             False
# 1      9/3/1966             1966             1             False
# 2      9/4/1966             1966             1             False
# 3      9/9/1966             1966             2             False
# 4     9/10/1966             1966             1             False
#
#             team_home  score_home  score_away        team_away  \
# 0      Miami Dolphins        14.0        23.0  Oakland Raiders
# 1      Houston Oilers        45.0         7.0   Denver Broncos
# 2  San Diego Chargers        27.0         7.0    Buffalo Bills
# 3      Miami Dolphins        14.0        19.0    New York Jets
# 4   Green Bay Packers        24.0         3.0  Baltimore Colts
#
#   team_favorite_id  spread_favorite over_under_line         stadium  \
# 0              NaN              NaN             NaN     Orange Bowl
# 1              NaN              NaN             NaN    Rice Stadium
# 2              NaN              NaN             NaN  Balboa Stadium
# 3              NaN              NaN             NaN     Orange Bowl
# 4              NaN              NaN             NaN   Lambeau Field
#
#    stadium_neutral  weather_temperature  weather_wind_mph  weather_humidity  \
# 0            False                 83.0               6.0              71.0
# 1            False                 81.0               7.0              70.0
# 2            False                 70.0               7.0              82.0
# 3            False                 82.0              11.0              78.0
# 4            False                 64.0               8.0              62.0
#
#   weather_detail
# 0            NaN
# 1            NaN
# 2            NaN
# 3            NaN
# 4            NaN

# %%
df.dtypes
# Out:
# schedule_date           object
# schedule_season          int64
# schedule_week           object
# schedule_playoff          bool
# team_home               object
# score_home             float64
# score_away             float64
# team_away               object
# team_favorite_id        object
# spread_favorite        float64
# over_under_line         object
# stadium                 object
# stadium_neutral           bool
# weather_temperature    float64
# weather_wind_mph       float64
# weather_humidity       float64
# weather_detail          object
# dtype: object

# %%
# Convert the schedule_date from object to datetime
df['schedule_date'] = pd.to_datetime(df['schedule_date'])
df.dtypes
# Out:
# schedule_date          datetime64[ns]
# schedule_season                 int64
# schedule_week                  object
# schedule_playoff                 bool
# team_home                      object
# score_home                    float64
# score_away                    float64
# team_away                      object
# team_favorite_id               object
# spread_favorite               float64
# over_under_line                object
# stadium                        object
# stadium_neutral                  bool
# weather_temperature           float64
# weather_wind_mph              float64
# weather_humidity              float64
# weather_detail                 object
# dtype: object

# %%
# Remove NAN Data that doesn't have a spread and over_under_line. We only want to look at data that has both of these
spread_df = df[~df['spread_favorite'].isnull()]
spread_df  = spread_df = df[~df['over_under_line'].isnull()]
spread_df
# Out:
#       schedule_date  schedule_season schedule_week  schedule_playoff  \
# 350      1968-01-14             1967     Superbowl              True
# 538      1969-01-12             1968     Superbowl              True
# 727      1970-01-11             1969     Superbowl              True
# 916      1971-01-17             1970     Superbowl              True
# 1105     1972-01-16             1971     Superbowl              True
# ...             ...              ...           ...               ...
# 13321    2022-10-16             2022             6             False
# 13322    2022-10-16             2022             6             False
# 13323    2022-10-16             2022             6             False
# 13324    2022-10-16             2022             6             False
# 13325    2022-10-17             2022             6             False
#
#                   team_home  score_home  score_away             team_away  \
# 350       Green Bay Packers        33.0        14.0       Oakland Raiders
# 538         Baltimore Colts         7.0        16.0         New York Jets
# 727      Kansas City Chiefs        23.0         7.0     Minnesota Vikings
# 916         Baltimore Colts        16.0        13.0        Dallas Cowboys
# 1105         Dallas Cowboys        24.0         3.0        Miami Dolphins
# ...                     ...         ...         ...                   ...
# 13321       New York Giants        24.0        20.0      Baltimore Ravens
# 13322   Philadelphia Eagles        26.0        17.0        Dallas Cowboys
# 13323   Pittsburgh Steelers        20.0        18.0  Tampa Bay Buccaneers
# 13324      Seattle Seahawks        19.0         9.0     Arizona Cardinals
# 13325  Los Angeles Chargers        19.0        16.0        Denver Broncos
#
#       team_favorite_id  spread_favorite over_under_line  \
# 350                 GB            -13.5              43
# 538                IND            -18.0              40
# 727                MIN            -12.0              39
# 916                IND             -2.5              36
# 1105               DAL             -6.0              34
# ...                ...              ...             ...
# 13321              BAL             -5.5            45.5
# 13322              PHI             -6.5            42.5
# 13323               TB            -10.0            46.5
# 13324              ARI             -2.5            50.5
# 13325              LAC             -4.0            45.5
#
#                        stadium  stadium_neutral  weather_temperature  \
# 350                Orange Bowl             True                 60.0
# 538                Orange Bowl             True                 66.0
# 727             Tulane Stadium             True                 55.0
# 916                Orange Bowl             True                 59.0
# 1105            Tulane Stadium             True                 34.0
# ...                        ...              ...                  ...
# 13321          MetLife Stadium            False                  NaN
# 13322  Lincoln Financial Field            False                  NaN
# 13323         Acrisure Stadium            False                  NaN
# 13324              Lumen Field            False                  NaN
# 13325             SoFi Stadium            False                 72.0
#
#        weather_wind_mph  weather_humidity weather_detail
# 350                12.0              74.0            NaN
# 538                12.0              80.0           Rain
# 727                14.0              84.0           Rain
# 916                11.0              60.0            NaN
# 1105               18.0              40.0            NaN
# ...                 ...               ...            ...
# 13321               NaN               NaN            NaN
# 13322               NaN               NaN            NaN
# 13323               NaN               NaN            NaN
# 13324               NaN               NaN            NaN
# 13325               0.0               NaN           DOME
#
# [10837 rows x 17 columns]

# %%
# Only return data for the last 10 seasons
spread_df = spread_df.loc[spread_df['schedule_season'] > 2011]
# Alternate way to do the same thing above
# spread_df = spread_df[spread_df['schedule_season'] > 2011]
spread_df['schedule_season'].unique().tolist()
# Out:
# [2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019, 2020, 2021, 2022]

# %%
# Only Returns the Columns that we are going to work with
spread_df = spread_df[['schedule_season', 'schedule_week', 'schedule_playoff', 'team_home', 'team_away', 'score_home', 'score_away', 'team_favorite_id', 'spread_favorite', 'over_under_line', 'stadium_neutral']]
spread_df
# Out:
#        schedule_season schedule_week  schedule_playoff             team_home  \
# 10542             2012             1             False       New York Giants
# 10543             2012             1             False     Arizona Cardinals
# 10544             2012             1             False         Chicago Bears
# 10545             2012             1             False      Cleveland Browns
# 10546             2012             1             False        Denver Broncos
# ...                ...           ...               ...                   ...
# 13321             2022             6             False       New York Giants
# 13322             2022             6             False   Philadelphia Eagles
# 13323             2022             6             False   Pittsburgh Steelers
# 13324             2022             6             False      Seattle Seahawks
# 13325             2022             6             False  Los Angeles Chargers
#
#                   team_away  score_home  score_away team_favorite_id  \
# 10542        Dallas Cowboys        17.0        24.0              NYG
# 10543      Seattle Seahawks        20.0        16.0              SEA
# 10544    Indianapolis Colts        41.0        21.0              CHI
# 10545   Philadelphia Eagles        16.0        17.0              PHI
# 10546   Pittsburgh Steelers        31.0        19.0              DEN
# ...                     ...         ...         ...              ...
# 13321      Baltimore Ravens        24.0        20.0              BAL
# 13322        Dallas Cowboys        26.0        17.0              PHI
# 13323  Tampa Bay Buccaneers        20.0        18.0               TB
# 13324     Arizona Cardinals        19.0         9.0              ARI
# 13325        Denver Broncos        19.0        16.0              LAC
#
#        spread_favorite over_under_line  stadium_neutral
# 10542             -4.0              46            False
# 10543             -3.0              41            False
# 10544            -10.0            42.5            False
# 10545             -9.5              42            False
# 10546             -2.0            45.5            False
# ...                ...             ...              ...
# 13321             -5.5            45.5            False
# 13322             -6.5            42.5            False
# 13323            -10.0            46.5            False
# 13324             -2.5            50.5            False
# 13325             -4.0            45.5            False
#
# [2784 rows x 11 columns]

# %%
# Remove playoff games and games played at neautral locations then drop these columns
spread_df = spread_df.loc[(spread_df['schedule_playoff'] == False) & (spread_df['stadium_neutral'] == False)]
spread_df = spread_df.drop(columns=['schedule_playoff', 'stadium_neutral'])
spread_df = spread_df.reset_index()

# %%
# Add Total Score from both teams
spread_df['Total_Score'] = spread_df['score_home'] + spread_df['score_away']
spread_df
# Out:
#       index  schedule_season schedule_week             team_home  \
# 0     10542             2012             1       New York Giants
# 1     10543             2012             1     Arizona Cardinals
# 2     10544             2012             1         Chicago Bears
# 3     10545             2012             1      Cleveland Browns
# 4     10546             2012             1        Denver Broncos
# ...     ...              ...           ...                   ...
# 2631  13321             2022             6       New York Giants
# 2632  13322             2022             6   Philadelphia Eagles
# 2633  13323             2022             6   Pittsburgh Steelers
# 2634  13324             2022             6      Seattle Seahawks
# 2635  13325             2022             6  Los Angeles Chargers
#
#                  team_away  score_home  score_away team_favorite_id  \
# 0           Dallas Cowboys        17.0        24.0              NYG
# 1         Seattle Seahawks        20.0        16.0              SEA
# 2       Indianapolis Colts        41.0        21.0              CHI
# 3      Philadelphia Eagles        16.0        17.0              PHI
# 4      Pittsburgh Steelers        31.0        19.0              DEN
# ...                    ...         ...         ...              ...
# 2631      Baltimore Ravens        24.0        20.0              BAL
# 2632        Dallas Cowboys        26.0        17.0              PHI
# 2633  Tampa Bay Buccaneers        20.0        18.0               TB
# 2634     Arizona Cardinals        19.0         9.0              ARI
# 2635        Denver Broncos        19.0        16.0              LAC
#
#       spread_favorite over_under_line  Total_Score
# 0                -4.0              46         41.0
# 1                -3.0              41         36.0
# 2               -10.0            42.5         62.0
# 3                -9.5              42         33.0
# 4                -2.0            45.5         50.0
# ...               ...             ...          ...
# 2631             -5.5            45.5         44.0
# 2632             -6.5            42.5         43.0
# 2633            -10.0            46.5         38.0
# 2634             -2.5            50.5         28.0
# 2635             -4.0            45.5         35.0
#
# [2636 rows x 11 columns]

# %%
# Change over_under_line to float so I can compare to total score to figure out if it went over/under/pushed
spread_df['over_under_line'] = spread_df['over_under_line'].astype(float)
spread_df['Over_Total_Points'] = np.where(spread_df['Total_Score'] > spread_df['over_under_line'], 'Yes',
                           np.where(spread_df['Total_Score'] < spread_df['over_under_line'], 'No', 'Push'))
# spread_df['Over_Spread'].unique().tolist()
spread_df
# Out:
#       index  schedule_season schedule_week             team_home  \
# 0     10542             2012             1       New York Giants
# 1     10543             2012             1     Arizona Cardinals
# 2     10544             2012             1         Chicago Bears
# 3     10545             2012             1      Cleveland Browns
# 4     10546             2012             1        Denver Broncos
# ...     ...              ...           ...                   ...
# 2631  13321             2022             6       New York Giants
# 2632  13322             2022             6   Philadelphia Eagles
# 2633  13323             2022             6   Pittsburgh Steelers
# 2634  13324             2022             6      Seattle Seahawks
# 2635  13325             2022             6  Los Angeles Chargers
#
#                  team_away  score_home  score_away team_favorite_id  \
# 0           Dallas Cowboys        17.0        24.0              NYG
# 1         Seattle Seahawks        20.0        16.0              SEA
# 2       Indianapolis Colts        41.0        21.0              CHI
# 3      Philadelphia Eagles        16.0        17.0              PHI
# 4      Pittsburgh Steelers        31.0        19.0              DEN
# ...                    ...         ...         ...              ...
# 2631      Baltimore Ravens        24.0        20.0              BAL
# 2632        Dallas Cowboys        26.0        17.0              PHI
# 2633  Tampa Bay Buccaneers        20.0        18.0               TB
# 2634     Arizona Cardinals        19.0         9.0              ARI
# 2635        Denver Broncos        19.0        16.0              LAC
#
#       spread_favorite  over_under_line  Total_Score Over_Total_Points
# 0                -4.0             46.0         41.0                No
# 1                -3.0             41.0         36.0                No
# 2               -10.0             42.5         62.0               Yes
# 3                -9.5             42.0         33.0                No
# 4                -2.0             45.5         50.0               Yes
# ...               ...              ...          ...               ...
# 2631             -5.5             45.5         44.0                No
# 2632             -6.5             42.5         43.0               Yes
# 2633            -10.0             46.5         38.0                No
# 2634             -2.5             50.5         28.0                No
# 2635             -4.0             45.5         35.0                No
#
# [2636 rows x 12 columns]

# %%
# Alter team names that have changed over the last 10 years to the current team name
# spread_df.loc[df['team_home'] == 'San Diego Chargers', 'team_home'] = 'Los Angeles Chargers'
# spread_df.loc[df['team_home'] == 'Oakland Raiders', 'team_home'] = 'Las Vegas Raiders'

# df['team_home'] = np.where(df['team_home'] == 'San Diego Chargers', 'Los Angeles Chargers', df['team_home'])

# df['team_home'] = df['team_home'].mask(df['team_home'] == 'San Diego Chargers', 'Los Angeles Chargers' , inplace=True)

spread_df.loc[spread_df['team_home'] == 'San Diego Chargers', 'team_home'] = 'Los Angeles Chargers'
spread_df.loc[spread_df['team_home'] == 'St. Louis Rams', 'team_home'] = 'Los Angeles Rams'
spread_df.loc[spread_df['team_home'] == 'Oakland Raiders', 'team_home'] = 'Las Vegas Raiders'
spread_df.loc[spread_df['team_home'] == 'Washington Football Team', 'team_home'] = 'Washington Commanders'
spread_df.loc[spread_df['team_home'] == 'Washington Redskins', 'team_home'] = 'Washington Commanders'

spread_df.loc[spread_df['team_away'] == 'San Diego Chargers', 'team_away'] = 'Los Angeles Chargers'
spread_df.loc[spread_df['team_away'] == 'St. Louis Rams', 'team_away'] = 'Los Angeles Rams'
spread_df.loc[spread_df['team_away'] == 'Oakland Raiders', 'team_away'] = 'Las Vegas Raiders'
spread_df.loc[spread_df['team_away'] == 'Washington Football Team', 'team_away'] = 'Washington Commanders'
spread_df.loc[spread_df['team_away'] == 'Washington Redskins', 'team_away'] = 'Washington Commanders'

# spread_df.to_excel('dannytest.xlsx')
# pd.concat([spread_df['team_home'], spread_df['team_favorite_id']]).unique()

# %%
# Bring in a CSV breaking down team abbreviation so I can compare Favorite to a team
# PICK means that there isn't a favorite and they are equal
team_df = pd.read_csv("TeamABV.csv")
team_df
# Out:
#    Abbreviation          Team_Favorite
# 0           NYG        New York Giants
# 1           SEA       Seattle Seahawks
# 2           CHI          Chicago Bears
# 3           PHI    Philadelphia Eagles
# 4           DEN         Denver Broncos
# 5           DET          Detroit Lions
# 6            GB      Green Bay Packers
# 7           HOU         Houston Texans
# 8           ATL        Atlanta Falcons
# 9           MIN      Minnesota Vikings
# 10           NO     New Orleans Saints
# 11          NYJ          New York Jets
# 12          CAR      Carolina Panthers
# 13           NE   New England Patriots
# 14          BAL       Baltimore Ravens
# 15          LVR      Las Vegas Raiders
# 16          BUF          Buffalo Bills
# 17          CIN     Cincinnati Bengals
# 18          PIT    Pittsburgh Steelers
# 19          LAC   Los Angeles Chargers
# 20           SF    San Francisco 49ers
# 21          DAL         Dallas Cowboys
# 22          WAS  Washington Commanders
# 23          IND     Indianapolis Colts
# 24          ARI      Arizona Cardinals
# 25          JAX   Jacksonville Jaguars
# 26           TB   Tampa Bay Buccaneers
# 27          MIA         Miami Dolphins
# 28           KC     Kansas City Chiefs
# 29          TEN       Tennessee Titans
# 30          LAR       Los Angeles Rams
# 31          CLE       Cleveland Browns
# 32         PICK                   None

# %%
bet_df = ps.sqldf("Select * FROM spread_df sdf join team_df tdf on sdf.team_favorite_id	 = tdf.Abbreviation")
bet_df
# Out:
#       index  schedule_season schedule_week             team_home  \
# 0     10542             2012             1       New York Giants
# 1     10543             2012             1     Arizona Cardinals
# 2     10544             2012             1         Chicago Bears
# 3     10545             2012             1      Cleveland Browns
# 4     10546             2012             1        Denver Broncos
# ...     ...              ...           ...                   ...
# 2631  13321             2022             6       New York Giants
# 2632  13322             2022             6   Philadelphia Eagles
# 2633  13323             2022             6   Pittsburgh Steelers
# 2634  13324             2022             6      Seattle Seahawks
# 2635  13325             2022             6  Los Angeles Chargers
#
#                  team_away  score_home  score_away team_favorite_id  \
# 0           Dallas Cowboys        17.0        24.0              NYG
# 1         Seattle Seahawks        20.0        16.0              SEA
# 2       Indianapolis Colts        41.0        21.0              CHI
# 3      Philadelphia Eagles        16.0        17.0              PHI
# 4      Pittsburgh Steelers        31.0        19.0              DEN
# ...                    ...         ...         ...              ...
# 2631      Baltimore Ravens        24.0        20.0              BAL
# 2632        Dallas Cowboys        26.0        17.0              PHI
# 2633  Tampa Bay Buccaneers        20.0        18.0               TB
# 2634     Arizona Cardinals        19.0         9.0              ARI
# 2635        Denver Broncos        19.0        16.0              LAC
#
#       spread_favorite  over_under_line  Total_Score Over_Total_Points  \
# 0                -4.0             46.0         41.0                No
# 1                -3.0             41.0         36.0                No
# 2               -10.0             42.5         62.0               Yes
# 3                -9.5             42.0         33.0                No
# 4                -2.0             45.5         50.0               Yes
# ...               ...              ...          ...               ...
# 2631             -5.5             45.5         44.0                No
# 2632             -6.5             42.5         43.0               Yes
# 2633            -10.0             46.5         38.0                No
# 2634             -2.5             50.5         28.0                No
# 2635             -4.0             45.5         35.0                No
#
#      Abbreviation         Team_Favorite
# 0             NYG       New York Giants
# 1             SEA      Seattle Seahawks
# 2             CHI         Chicago Bears
# 3             PHI   Philadelphia Eagles
# 4             DEN        Denver Broncos
# ...           ...                   ...
# 2631          BAL      Baltimore Ravens
# 2632          PHI   Philadelphia Eagles
# 2633           TB  Tampa Bay Buccaneers
# 2634          ARI     Arizona Cardinals
# 2635          LAC  Los Angeles Chargers
#
# [2636 rows x 14 columns]

# %%
# Rearrange the columns and remove columns we don't need
nfl_df = bet_df[['schedule_season', 'schedule_week', 'team_home', 'team_away', 'Team_Favorite', 'spread_favorite', 'score_home', 'score_away', 'over_under_line', 'Total_Score', 'Over_Total_Points']]
nfl_df
# Out:
#       schedule_season schedule_week             team_home  \
# 0                2012             1       New York Giants
# 1                2012             1     Arizona Cardinals
# 2                2012             1         Chicago Bears
# 3                2012             1      Cleveland Browns
# 4                2012             1        Denver Broncos
# ...               ...           ...                   ...
# 2631             2022             6       New York Giants
# 2632             2022             6   Philadelphia Eagles
# 2633             2022             6   Pittsburgh Steelers
# 2634             2022             6      Seattle Seahawks
# 2635             2022             6  Los Angeles Chargers
#
#                  team_away         Team_Favorite  spread_favorite  score_home  \
# 0           Dallas Cowboys       New York Giants             -4.0        17.0
# 1         Seattle Seahawks      Seattle Seahawks             -3.0        20.0
# 2       Indianapolis Colts         Chicago Bears            -10.0        41.0
# 3      Philadelphia Eagles   Philadelphia Eagles             -9.5        16.0
# 4      Pittsburgh Steelers        Denver Broncos             -2.0        31.0
# ...                    ...                   ...              ...         ...
# 2631      Baltimore Ravens      Baltimore Ravens             -5.5        24.0
# 2632        Dallas Cowboys   Philadelphia Eagles             -6.5        26.0
# 2633  Tampa Bay Buccaneers  Tampa Bay Buccaneers            -10.0        20.0
# 2634     Arizona Cardinals     Arizona Cardinals             -2.5        19.0
# 2635        Denver Broncos  Los Angeles Chargers             -4.0        19.0
#
#       score_away  over_under_line  Total_Score Over_Total_Points
# 0           24.0             46.0         41.0                No
# 1           16.0             41.0         36.0                No
# 2           21.0             42.5         62.0               Yes
# 3           17.0             42.0         33.0                No
# 4           19.0             45.5         50.0               Yes
# ...          ...              ...          ...               ...
# 2631        20.0             45.5         44.0                No
# 2632        17.0             42.5         43.0               Yes
# 2633        18.0             46.5         38.0                No
# 2634         9.0             50.5         28.0                No
# 2635        16.0             45.5         35.0                No
#
# [2636 rows x 11 columns]

# %%
# spread_df['Over_Total_Points'] = np.where(spread_df['Total_Score'] > spread_df['over_under_line'], 'Yes',
#                            np.where(spread_df['Total_Score'] < spread_df['over_under_line'], 'No', 'Push'))


# warnings.filterwarnings('ignore')

nfl_df['home_team_adjusted'] = np.where(nfl_df['team_home'] == nfl_df['Team_Favorite'], nfl_df['score_home'] + nfl_df['spread_favorite'],
                               np.where(nfl_df['team_home'] != nfl_df['Team_Favorite'], nfl_df['score_home'] - nfl_df['spread_favorite'], "Wrong"))

# bet_df.dtypes
nfl_df['home_team_adjusted'] = nfl_df['home_team_adjusted'].astype(float)


nfl_df['Spread_Winner'] = np.where(nfl_df['home_team_adjusted'] > nfl_df['score_away'], nfl_df['team_home'],
                           np.where(nfl_df['score_away'] > nfl_df['home_team_adjusted'], nfl_df['team_away'], 'Push'))

nfl_df

# nfl_df.to_excel('dannytest2.xlsx')
# Out:
#       schedule_season schedule_week             team_home  \
# 0                2012             1       New York Giants
# 1                2012             1     Arizona Cardinals
# 2                2012             1         Chicago Bears
# 3                2012             1      Cleveland Browns
# 4                2012             1        Denver Broncos
# ...               ...           ...                   ...
# 2631             2022             6       New York Giants
# 2632             2022             6   Philadelphia Eagles
# 2633             2022             6   Pittsburgh Steelers
# 2634             2022             6      Seattle Seahawks
# 2635             2022             6  Los Angeles Chargers
#
#                  team_away         Team_Favorite  spread_favorite  score_home  \
# 0           Dallas Cowboys       New York Giants             -4.0        17.0
# 1         Seattle Seahawks      Seattle Seahawks             -3.0        20.0
# 2       Indianapolis Colts         Chicago Bears            -10.0        41.0
# 3      Philadelphia Eagles   Philadelphia Eagles             -9.5        16.0
# 4      Pittsburgh Steelers        Denver Broncos             -2.0        31.0
# ...                    ...                   ...              ...         ...
# 2631      Baltimore Ravens      Baltimore Ravens             -5.5        24.0
# 2632        Dallas Cowboys   Philadelphia Eagles             -6.5        26.0
# 2633  Tampa Bay Buccaneers  Tampa Bay Buccaneers            -10.0        20.0
# 2634     Arizona Cardinals     Arizona Cardinals             -2.5        19.0
# 2635        Denver Broncos  Los Angeles Chargers             -4.0        19.0
#
#       score_away  over_under_line  Total_Score Over_Total_Points  \
# 0           24.0             46.0         41.0                No
# 1           16.0             41.0         36.0                No
# 2           21.0             42.5         62.0               Yes
# 3           17.0             42.0         33.0                No
# 4           19.0             45.5         50.0               Yes
# ...          ...              ...          ...               ...
# 2631        20.0             45.5         44.0                No
# 2632        17.0             42.5         43.0               Yes
# 2633        18.0             46.5         38.0                No
# 2634         9.0             50.5         28.0                No
# 2635        16.0             45.5         35.0                No
#
#       home_team_adjusted        Spread_Winner
# 0                   13.0       Dallas Cowboys
# 1                   23.0    Arizona Cardinals
# 2                   31.0        Chicago Bears
# 3                   25.5     Cleveland Browns
# 4                   29.0       Denver Broncos
# ...                  ...                  ...
# 2631                29.5      New York Giants
# 2632                19.5  Philadelphia Eagles
# 2633                30.0  Pittsburgh Steelers
# 2634                21.5     Seattle Seahawks
# 2635                15.0       Denver Broncos
#
# [2636 rows x 13 columns]
